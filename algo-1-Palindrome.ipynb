# %% [markdown]
# **Using first Algorithm**

# %% [markdown]
# - Reverse the string
# - Compare the reversed string to the original

# %%
def is_palindrome(s):
    """ 
    (str) -> bool
    Return True if and only if s is a palindrome.
    >>> is_palindrome('noon')
    True
    >>> is_palindrome('racecar')
    True
    >>> is_palindrome('dented')
    False
    """
    return reverse(s)==s
def reverse(s):
    """ (str) -> str
    Return a reversed version of s
    >>> reverse('hello')
    'olleh'
    >>> reverse('a')
    'a'
    """
    rev = ''
    for ch in s :
        rev = ch +rev
    return rev 

print(reverse('hello'))
print(reverse('a'))

print(is_palindrome('noon'))
print(is_palindrome('racecar'))
print(is_palindrome('dented'))
# Out:
# olleh
# a
# True
# True
# False

# %% [markdown]
# **Using second Algorithm**

# %% [markdown]
# - Split the string into two halves
# - Reverse the second half
# - Compare the first half to the reversed second half

# %%
def is_palindrome(s):
    """ 
    (str) -> bool
    Return True if and only if s is a palindrome.
    >>> is_palindrome('noon')
    True
    >>> is_palindrome('racecar')
    True
    >>> is_palindrome('dented')
    False
    """
    n = len(s)
    # USING a slice [x:y]  includes the element at index x but not at y.
    return s [:n // 2] == reverse(s[n-n//2:])
    
def reverse(s):
    """ (str) -> str
    Return a reversed version of s
    >>> reverse('hello')
    'olleh'
    >>> reverse('a')
    'a'
    """
    rev = ''
    for ch in s :
        rev = ch +rev
    return rev 
print(is_palindrome('noon'))
print(is_palindrome('racecar'))
print(is_palindrome('dented'))
# Out:
# True
# True
# False

# %% [markdown]
# **Using third Algorithm**

# %% [markdown]
# - Compare the 1st character to the last character
# - Compare the 2nd character to the second last character
# ...
# - Stop when the middle of the string is reached

# %%
def is_palindrome(s):
    """ 
    (str) -> bool
    Return True if and only if s is a palindrome.
    >>> is_palindrome('noon')
    True
    >>> is_palindrome('racecar')
    True
    >>> is_palindrome('dented')
    False
    """
    i=0
    j=len(s)-1 
    while i < j and s[i]==s[j]: 
        i += 1
        j -= 1
    return j <=i

print(is_palindrome('noon'))
print(is_palindrome('racecar'))
print(is_palindrome('dented'))
# Out:
# True
# True
# False
